# %% [markdown]
# <a href="https://colab.research.google.com/github/konradplonka/machine-learning-bootcamp/blob/main/01_basics/03_feature_extraction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader as pdr

# %% [markdown]
# # Załadowanie danych

# %%
def fetch_financial_data(company='AMZN'):
  return pdr.stooq.StooqDailyReader(symbols=company).read()

df_raw = fetch_financial_data()
df_raw.head()
# Out:
#                Open      High     Low   Close    Volume
# Date
# 2025-01-03  222.505  225.3600  221.62  224.19  27515606
# 2025-01-02  222.030  225.1500  218.19  220.22  33956579
# 2024-12-31  222.965  223.2299  218.94  219.39  24819655
# 2024-12-30  220.060  222.9972  218.43  221.30  28321240
# 2024-12-27  225.600  226.0300  220.90  223.75  27367147

# %% [markdown]
# # Utworzenie kopii danych

# %%
df = df_raw.copy()
df = df[:5]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5 entries, 2025-01-03 to 2024-12-27
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    5 non-null      float64
#  1   High    5 non-null      float64
#  2   Low     5 non-null      float64
#  3   Close   5 non-null      float64
#  4   Volume  5 non-null      int64
# dtypes: float64(4), int64(1)
# memory usage: 240.0 bytes

# %% [markdown]
# # Generowanie nowych zmiennych

# %%
df['day'] = df.index.day
df['month'] = df.index.month
df['year'] = df.index.year

df
# Out:
#                Open      High     Low   Close    Volume  day  month  year
# Date
# 2025-01-03  222.505  225.3600  221.62  224.19  27515606    3      1  2025
# 2025-01-02  222.030  225.1500  218.19  220.22  33956579    2      1  2025
# 2024-12-31  222.965  223.2299  218.94  219.39  24819655   31     12  2024
# 2024-12-30  220.060  222.9972  218.43  221.30  28321240   30     12  2024
# 2024-12-27  225.600  226.0300  220.90  223.75  27367147   27     12  2024

# %% [markdown]
# # Dyskretyzacja zmiennej ciągłej

# %%
df = pd.DataFrame(data={'height': [175., 178.5, 185., 191., 184.5, 183., 168.]})
df
# Out:
#    height
# 0   175.0
# 1   178.5
# 2   185.0
# 3   191.0
# 4   184.5
# 5   183.0
# 6   168.0

# %%
df['height_cat'] = pd.cut(x=df['height'], bins=3)
df
# Out:
#    height          height_cat
# 0   175.0  (167.977, 175.667]
# 1   178.5  (175.667, 183.333]
# 2   185.0    (183.333, 191.0]
# 3   191.0    (183.333, 191.0]
# 4   184.5    (183.333, 191.0]
# 5   183.0  (175.667, 183.333]
# 6   168.0  (167.977, 175.667]

# %%
df['height_cat'] = pd.cut(x=df['height'], bins=(160, 175, 180, 195))
df
# Out:
#    height  height_cat
# 0   175.0  (160, 175]
# 1   178.5  (175, 180]
# 2   185.0  (180, 195]
# 3   191.0  (180, 195]
# 4   184.5  (180, 195]
# 5   183.0  (180, 195]
# 6   168.0  (160, 175]

# %%
df['height_cat'] = pd.cut(x=df['height'], bins=(160, 175, 180, 195), labels=['small', 'medium', 'high'])
df
# Out:
#    height height_cat
# 0   175.0      small
# 1   178.5     medium
# 2   185.0       high
# 3   191.0       high
# 4   184.5       high
# 5   183.0       high
# 6   168.0      small

# %%
pd.get_dummies(df, drop_first=True, prefix='height')
# Out:
#    height  height_medium  height_high
# 0   175.0          False        False
# 1   178.5           True        False
# 2   185.0          False         True
# 3   191.0          False         True
# 4   184.5          False         True
# 5   183.0          False         True
# 6   168.0          False        False

# %% [markdown]
# # Ekstracja cech

# %%
df = pd.DataFrame(data={'lang': [['PL', 'ENG'], ['GER', 'ENG', 'PL', 'FRA'], ['RUS']]})
df
# Out:
#                   lang
# 0            [PL, ENG]
# 1  [GER, ENG, PL, FRA]
# 2                [RUS]

# %%
df['lang_number'] = df['lang'].apply(len)
df
# Out:
#                   lang  lang_number
# 0            [PL, ENG]            2
# 1  [GER, ENG, PL, FRA]            4
# 2                [RUS]            1

# %%
df['PL_flag'] = df['lang'].apply(lambda x: 1 if 'PL' in x else 0)
df
# Out:
#                   lang  lang_number  PL_flag
# 0            [PL, ENG]            2        1
# 1  [GER, ENG, PL, FRA]            4        1
# 2                [RUS]            1        0

# %%
df = pd.DataFrame(data={'website': ['wp.pl', 'onet.pl', 'google.com']})
df
# Out:
#       website
# 0       wp.pl
# 1     onet.pl
# 2  google.com

# %%
df[['portal', 'extension']]=df['website'].str.split('.', expand=True)
df
# Out:
#       website  portal extension
# 0       wp.pl      wp        pl
# 1     onet.pl    onet        pl
# 2  google.com  google       com
